# %%
import pandas
df = pandas.read_csv('quecoche_items_parsed.csv',encoding='utf-8')
df
# Out:
#                                            Nombre      Marca  Modelo  \
# 0        Chevrolet Zafira 2004 5 puerta full full  chevrolet  Zafira
# 1                           Chevrolet Zafira 2005  chevrolet  Zafira
# 2                           Chevrolet Zafira 2004  chevrolet  Zafira
# 3                      Chevrolet Zafira 2007 Full  chevrolet  Zafira
# 4        Chevrolet Zafira 2005 2.0 16v 7 asientos  chevrolet  Zafira
# ...                                           ...        ...     ...
# 7444        Audi A1 2015 3 puertas sline 1.4 90cv       audi      A1
# 7445          Audi A1 2011 2 PUERTAS VERSION ENVY       audi      A1
# 7446              Audi A1 2012 Audi A1 autimatico       audi      A1
# 7447                 Audi A1 2012 SLine 2 puertas       audi      A1
# 7448  Audi 80 1993 Berlina 4 puertas 19 tdi 90 cv       audi      80
#
#       Estrellas                                            Opinion  Votos  \
# ...

# %%
df[['Sentimiento','P_positivo','P_negativo','P_neutral','P_mixto','keyPhrases','Scores']]
# Out:
#      Sentimiento  P_positivo  P_negativo  P_neutral   P_mixto  \
# 0       NEGATIVE    0.135805    0.803450   0.059899  0.000847
# 1          MIXED    0.001671    0.000801   0.000351  0.997177
# 2       NEGATIVE    0.419466    0.419685   0.100985  0.059864
# 3          MIXED    0.040019    0.005477   0.005676  0.948828
# 4          MIXED    0.002299    0.000190   0.000026  0.997485
# ...          ...         ...         ...        ...       ...
# 7444    NEGATIVE    0.008760    0.951834   0.003291  0.036114
# 7445       MIXED    0.297905    0.024900   0.010281  0.666914
# 7446    NEGATIVE    0.026856    0.905729   0.065135  0.002280
# 7447    POSITIVE    0.999301    0.000035   0.000661  0.000002
# 7448    POSITIVE    0.992521    0.000838   0.006597  0.000044
#
#                                              keyPhrases  \
# 0                                                   NaN
# 1                                                   NaN
# ...
